# %% [markdown]
# ## Setting up the Working Directory
# This cell is to ensure we change the directory to anomalib source code to have access to the datasets and config files. We assume that you already went through `001_getting_started.ipynb` and install the required packages.

# %%
import os
from functools import partial, update_wrapper
from pathlib import Path
from types import MethodType
from typing import Any



current_directory = Path.cwd()
if current_directory.name == "200_models":
    # On the assumption that, the notebook is located in
    #   ~/anomalib/notebooks/100_datamodules/
    root_directory = current_directory.parent.parent
elif current_directory.name == "anomalib":
    # This means that the notebook is run from the main anomalib directory.
    root_directory = current_directory
else:
    from git.repo import Repo
    # Otherwise, we'll need to clone the anomalib repo to the `current_directory`
    repo = Repo.clone_from(url="https://github.com/openvinotoolkit/anomalib.git", to_path=current_directory)
    root_directory = current_directory / "anomalib"

root_directory = "/scratch/ssenth21/aggr_miniJSRT"
os.chdir(root_directory)
print(type(root_directory))
#dataset_root = root_directory / "datasets" / "MVTec"
#dataset_root = root_directory / "datasets" / "autoencoder_img"
dataset_root = root_directory
# Out:
# <class 'str'>

# %% [markdown]
# # Train a Model via API
#
# This notebook demonstrates how to train, test and infer the FastFlow model via Anomalib API. Compared to the CLI entrypoints such as \`tools/\<train, test, inference>.py, the API offers more flexibility such as modifying the existing model or designing custom approaches.
#
# ## Imports

# %%
from matplotlib import pyplot as plt
from pytorch_lightning import LightningModule, Trainer
from pytorch_lightning.callbacks import EarlyStopping, ModelCheckpoint
from torch.optim import Optimizer
from torch.optim.adam import Adam
from torch.utils.data import DataLoader

from anomalib.data import InferenceDataset, TaskType
from anomalib.data.mvtec import MVTec
from anomalib.models.stfpm.lightning_model import Stfpm
from anomalib.post_processing import (
    NormalizationMethod,
    ThresholdMethod,
    superimpose_anomaly_map,
)
from anomalib.pre_processing.transforms import Denormalize
from anomalib.utils.callbacks import (
    ImageVisualizerCallback,
    MetricsConfigurationCallback,
    MetricVisualizerCallback,
    PostProcessingConfigurationCallback,
)
from anomalib.data.folder import Folder, FolderDataset
from anomalib.data.utils import InputNormalizationMethod, get_transforms

# %% [markdown]
# ## Data Module
#
# To train the model end-to-end, we do need to have a dataset. In our [previous notebooks](https://github.com/openvinotoolkit/anomalib/tree/main/notebooks/100_datamodules), we demonstrate how to initialize benchmark- and custom datasets. In this tutorial, we will use MVTec AD DataModule. We assume that `datasets` directory is created in the `anomalib` root directory and `MVTec` dataset is located in `datasets` directory.
#
# Before creating the dataset, let's define the task type that we will be working on. In this notebook, we will be working on a segmentation task. Therefore the `task` variable would be:

# %% [raw]
# !cp -r /scratch/ssenth21/warmup_ex_contd/autoencoder_img /scratch/ssenth21/anomalib/datasets/autoencoder_img

# %%
task = TaskType.CLASSIFICATION
#task = TaskType.SEGMENTATION

# %%
Folder??
# Out:
# Init signature:
# Folder(
#     normal_dir: 'str | Path',
#     root: 'str | Path | None' = None,
#     abnormal_dir: 'str | Path | None' = None,
#     normal_test_dir: 'str | Path | None' = None,
#     mask_dir: 'str | Path | None' = None,
#     normal_split_ratio: 'float' = 0.2,
#     extensions: 'tuple[str] | None' = None,
#     image_size: 'int | tuple[int, int] | None' = None,
#     center_crop: 'int | tuple[int, int] | None' = None,
#     normalization: 'str | InputNormalizationMethod' = <InputNormalizationMethod.IMAGENET: 'imagenet'>,
#     train_batch_size: 'int' = 32,
#     eval_batch_size: 'int' = 32,
#     num_workers: 'int' = 8,
#     task: 'TaskType' = <TaskType.SEGMENTATION: 'segmentation'>,
#     transform_config_train: 'str | A.Compose | None' = None,
#     transform_config_eval: 'str | A.Compose | None' = None,
#     test_split_mode: 'TestSplitMode' = <TestSplitMode.FROM_DIR: 'from_dir'>,
#     test_split_ratio: 'float' = 0.2,
#     val_split_mode: 'ValSplitMode' = <ValSplitMode.FROM_TEST: 'from_test'>,
#     val_split_ratio: 'float' = 0.5,
#     seed: 'int | None' = None,
# ) -> 'None'
# Source:
# class Folder(AnomalibDataModule):
#     """Folder DataModule.
#     Args:
#         normal_dir (str | Path): Name of the directory containing normal images.
#             Defaults to "normal".
#         root (str | Path | None): Path to the root folder containing normal and abnormal dirs.
#         abnormal_dir (str | Path | None): Name of the directory containing abnormal images.
#             Defaults to "abnormal".
#         normal_test_dir (str | Path | None, optional): Path to the directory containing
#             normal images for the test dataset. Defaults to None.
#         mask_dir (str | Path | None, optional): Path to the directory containing
#             the mask annotations. Defaults to None.
#         normal_split_ratio (float, optional): Ratio to split normal training images and add to the
#             test set in case test set doesn't contain any normal images.
#             Defaults to 0.2.
#         extensions (tuple[str, ...] | None, optional): Type of the image extensions to read from the
#             directory. Defaults to None.
#         image_size (int | tuple[int, int] | None, optional): Size of the input image.
#             Defaults to None.
#         center_crop (int | tuple[int, int] | None, optional): When provided, the images will be center-cropped
#             to the provided dimensions.
#         normalize (bool): When True, the images will be normalized to the ImageNet statistics.
#         train_batch_size (int, optional): Training batch size. Defaults to 32.
#         test_batch_size (int, optional): Test batch size. Defaults to 32.
#         num_workers (int, optional): Number of workers. Defaults to 8.
#         task (TaskType, optional): Task type. Could be ``classification``, ``detection`` or ``segmentation``.
#             Defaults to segmentation.
#         transform_config_train (str | A.Compose | None, optional): Config for pre-processing
#             during training.
#             Defaults to None.
#         transform_config_val (str | A.Compose | None, optional): Config for pre-processing
#             during validation.
#             Defaults to None.
#         test_split_mode (TestSplitMode): Setting that determines how the testing subset is obtained.
#         test_split_ratio (float): Fraction of images from the train set that will be reserved for testing.
#         val_split_mode (ValSplitMode): Setting that determines how the validation subset is obtained.
#         val_split_ratio (float): Fraction of train or test images that will be reserved for validation.
#         seed (int | None, optional): Seed used during random subset splitting.
#     """
#
#     def __init__(
#         self,
#         normal_dir: str | Path,
#         root: str | Path | None = None,
#         abnormal_dir: str | Path | None = None,
#         normal_test_dir: str | Path | None = None,
#         mask_dir: str | Path | None = None,
#         normal_split_ratio: float = 0.2,
#         extensions: tuple[str] | None = None,
#         image_size: int | tuple[int, int] | None = None,
#         center_crop: int | tuple[int, int] | None = None,
#         normalization: str | InputNormalizationMethod = InputNormalizationMethod.IMAGENET,
#         train_batch_size: int = 32,
#         eval_batch_size: int = 32,
#         num_workers: int = 8,
#         task: TaskType = TaskType.SEGMENTATION,
#         transform_config_train: str | A.Compose | None = None,
#         transform_config_eval: str | A.Compose | None = None,
#         test_split_mode: TestSplitMode = TestSplitMode.FROM_DIR,
#         test_split_ratio: float = 0.2,
#         val_split_mode: ValSplitMode = ValSplitMode.FROM_TEST,
#         val_split_ratio: float = 0.5,
#         seed: int | None = None,
#     ) -> None:
#         super().__init__(
#             train_batch_size=train_batch_size,
#             eval_batch_size=eval_batch_size,
#             num_workers=num_workers,
#             test_split_mode=test_split_mode,
#             test_split_ratio=test_split_ratio,
#             val_split_mode=val_split_mode,
#             val_split_ratio=val_split_ratio,
#             seed=seed,
#         )
#
#         self.normal_split_ratio = normal_split_ratio
#
#         transform_train = get_transforms(
#             config=transform_config_train,
#             image_size=image_size,
#             center_crop=center_crop,
#             normalization=InputNormalizationMethod(normalization),
#         )
#         transform_eval = get_transforms(
#             config=transform_config_eval,
#             image_size=image_size,
#             center_crop=center_crop,
#             normalization=InputNormalizationMethod(normalization),
#         )
#
#         self.train_data = FolderDataset(
#             task=task,
#             transform=transform_train,
#             split=Split.TRAIN,
#             root=root,
#             normal_dir=normal_dir,
#             abnormal_dir=abnormal_dir,
#             normal_test_dir=normal_test_dir,
#             mask_dir=mask_dir,
#             extensions=extensions,
#         )
#
#         self.test_data = FolderDataset(
#             task=task,
#             transform=transform_eval,
#             split=Split.TEST,
#             root=root,
#             normal_dir=normal_dir,
#             abnormal_dir=abnormal_dir,
#             normal_test_dir=normal_test_dir,
#             mask_dir=mask_dir,
#             extensions=extensions,
#         )
# File:           /scratch/ssenth21/anomalib/src/anomalib/data/folder.py
# Type:           ABCMeta
# Subclasses:

# %%
datamodule = Folder(
    root="/scratch/ssenth21/aggr_miniJSRT/train/",
    normal_dir="org",
    abnormal_dir="flip",
    task=task,
    image_size=256,
    #normalization=InputNormalizationMethod.NONE,  # don't apply normalization, as we want to visualize the images
)
datamodule.setup()
i, data = next(enumerate(datamodule.test_dataloader()))
print(f'Image Shape: {data["image"].shape}')
# Out:
# Image Shape: torch.Size([32, 3, 256, 256])

# %% [raw]
# datamodule = MVTec(
#     root=dataset_root,
#     category="bottle",
#     image_size=256,
#     train_batch_size=32,
#     eval_batch_size=32,
#     num_workers=8,
#     task=task,
# )
# datamodule.setup()
# i, data = next(enumerate(datamodule.test_dataloader()))
# print(f'Image Shape: {data["image"].shape} Mask Shape: {data["mask"].shape}')

# %% [markdown]
# ## FastFlow Model
#
# Now that we have created the MVTec datamodule, we could create the FastFlow model. We could start with printing its docstring.

# %%
Stfpm??
# Out:
# Init signature: Stfpm(input_size: 'tuple[int, int]', backbone: 'str', layers: 'list[str]') -> 'None'
# Source:
# class Stfpm(AnomalyModule):
#     """PL Lightning Module for the STFPM algorithm.
#
#     Args:
#         input_size (tuple[int, int]): Size of the model input.
#         backbone (str): Backbone CNN network
#         layers (list[str]): Layers to extract features from the backbone CNN
#     """
#
#     def __init__(
#         self,
#         input_size: tuple[int, int],
#         backbone: str,
#         layers: list[str],
#     ) -> None:
#         super().__init__()
#
#         self.model = STFPMModel(
#             input_size=input_size,
#             backbone=backbone,
#             layers=layers,
#         )
#         self.loss = STFPMLoss()
#
#     def training_step(self, batch: dict[str, str | Tensor], *args, **kwargs) -> STEP_OUTPUT:
#         """Training Step of STFPM.
#
#         For each batch, teacher and student and teacher features are extracted from the CNN.
#
#         Args:
#           batch (dict[str, str | Tensor]): Input batch
#
#         Returns:
#           Loss value
#         """
#         del args, kwargs  # These variables are not used.
#
#         self.model.teacher_model.eval()
#         teacher_features, student_features = self.model.forward(batch["image"])
#         loss = self.loss(teacher_features, student_features)
#         self.log("train_loss", loss.item(), on_epoch=True, prog_bar=True, logger=True)
#         return {"loss": loss}
#
#     def validation_step(self, batch: dict[str, str | Tensor], *args, **kwargs) -> STEP_OUTPUT:
#         """Validation Step of STFPM.
#
#         Similar to the training step, student/teacher features are extracted from the CNN for each batch, and
#         anomaly map is computed.
#
#         Args:
#           batch (dict[str, str | Tensor]): Input batch
#
#         Returns:
#           Dictionary containing images, anomaly maps, true labels and masks.
#           These are required in `validation_epoch_end` for feature concatenation.
#         """
#         del args, kwargs  # These variables are not used.
#
#         batch["anomaly_maps"] = self.model(batch["image"])
#         return batch
# File:           /scratch/ssenth21/anomalib/src/anomalib/models/stfpm/lightning_model.py
# Type:           ABCMeta
# Subclasses:     StfpmLightning

# %%
model = Stfpm(input_size=(256, 256), backbone="resnet18", layers=["layer1", "layer2", "layer3"])
# Out:
# /home/ssenth21/.conda/envs/anomalib_env/lib/python3.8/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `PrecisionRecallCurve` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# FeatureExtractor is deprecated. Use TimmFeatureExtractor instead. Both FeatureExtractor and TimmFeatureExtractor will be removed in a future release.
# FeatureExtractor is deprecated. Use TimmFeatureExtractor instead. Both FeatureExtractor and TimmFeatureExtractor will be removed in a future release.

# %% [markdown]
# Depending on the `training` mode, `model` returns two different outputs. If the model is in `training` mode, it returns the hidden variable and the log of the jacobian, based on the feature maps.

# %%
model.training = True
train_output = model(data["image"])
hidden_variables, log_jacobian = train_output
print(f"Hidden Variable Shape: {hidden_variables['layer3'].shape}")
# Out:
# Hidden Variable Shape: torch.Size([32, 256, 16, 16])

# %% [markdown]
# During the test/inference mode, the model returns an anomaly heatmap localizing the anomalous regions.

# %%
model.model.training = False
anomaly_map = model(data["image"])
print(f"Anomaly Map Shape: {anomaly_map.shape}")
# Out:
# Anomaly Map Shape: torch.Size([32, 1, 256, 256])

# %% [markdown]
# ## Optimizer
#
# `LightningModule` has `configure_optimizer` method that returns the optimizer object. This is not implemented in the FastFlow model. Instead, it is left to the user to make it configurable by either CLI or API. Here we will be configuring it via the API. To do so, we first need to create the optimizer object, wrap it around a function and finally inject this function into the model class.

# %%
def configure_optimizers(lightning_module: LightningModule, optimizer: Optimizer) -> Any:  # pylint: disable=W0613,W0621
    """Override to customize the LightningModule.configure_optimizers` method."""
    return optimizer


optimizer = Adam(params=model.parameters(), lr=0.001, betas=(0.9, 0.999), weight_decay=1e-5)
fn = partial(configure_optimizers, optimizer=optimizer)
update_wrapper(fn, configure_optimizers)  # necessary for `is_overridden`
model.configure_optimizers = MethodType(fn, model)

# %% [markdown]
# ## Callbacks
#
# To train the model properly, we will to add some other "non-essential" logic such as saving the weights, early-stopping, normalizing the anomaly scores and visualizing the input/output images. To achieve these we use `Callbacks`. Anomalib has its own callbacks and also supports PyTorch Lightning's native callbacks. So, let's create the list of callbacks we want to execute during the training.

# %%
# !pwd
# Out:
# /scratch/ssenth21/aggr_miniJSRT

# %% [raw]
# import anomalib
# dir(anomalib.utils.metrics)

# %%
callbacks = [
    MetricsConfigurationCallback(
        task=task,
        image_metrics=["AUROC"],
        #pixel_metrics=["OptimalF1"],
    ),
    ModelCheckpoint(
        mode="min",
        monitor="train_loss",
        #monitor="image_AUROC",
    ),
    EarlyStopping(
        monitor="train_loss",
        #monitor="image_AUROC",
        mode="min",
        patience=3,
    ),
    PostProcessingConfigurationCallback(
        normalization_method=NormalizationMethod.MIN_MAX,
        threshold_method=ThresholdMethod.ADAPTIVE,
    ),
    ImageVisualizerCallback(mode="full", task=task, image_save_path="./stfpm_results/images"),
    MetricVisualizerCallback(mode="full", task=task, image_save_path="./stfpm_results/images"),
]

# %% [markdown]
# ## Training
#
# Now that we set up the datamodule, model, optimizer and the callbacks, we could now train the model.
#
# The final component to train the model is `pytorch_lightning` `Trainer` object, which handles train/test/predict pipeline. Let's create the trainer object to train the model.

# %%
trainer = Trainer(
    callbacks=callbacks,
    accelerator="gpu",  # \<"cpu", "gpu", "tpu", "ipu", "hpu", "auto">,
    devices=1,
    max_epochs=100,
)
# Out:
# /home/ssenth21/.conda/envs/anomalib_env/lib/python3.8/site-packages/lightning_fabric/plugins/environments/slurm.py:166: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /home/ssenth21/.conda/envs/anomalib_env/lib/python3. ...
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/ssenth21/.conda/envs/anomalib_env/lib/python3.8/site-packages/pytorch_lightning/trainer/connectors/logger_connector/logger_connector.py:67: UserWarning: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
#   warning_cache.warn(

# %% [markdown]
# `Trainer` object has number of options that suit all specific needs. For more details, refer to [Lightning Documentation](https://pytorch-lightning.readthedocs.io/en/stable/common/trainer.html) to see how it could be tweaked to your needs.
#
# Let's train the model now.

# %%
trainer.fit(datamodule=datamodule, model=model)
# Out:
# /home/ssenth21/.conda/envs/anomalib_env/lib/python3.8/site-packages/lightning_fabric/plugins/environments/slurm.py:166: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /home/ssenth21/.conda/envs/anomalib_env/lib/python3. ...
#   rank_zero_warn(
# /home/ssenth21/.conda/envs/anomalib_env/lib/python3.8/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `ROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name            | Type                     | Params
# -------------------------------------------------------------
# 0 | image_threshold | AnomalyScoreThreshold    | 0
# 1 | pixel_threshold | AnomalyScoreThreshold    | 0
# 2 | model           | STFPMModel               | 5.6 M
# 3 | loss            | STFPMLoss                | 0
# 4 | image_metrics   | AnomalibMetricCollection | 0
# 5 | pixel_metrics   | AnomalibMetricCollection | 0
# -------------------------------------------------------------
# 2.8 M     Trainable params
# 2.8 M     Non-trainable params
# 5.6 M     Total params
# 22.262    Total estimated model params size (MB)
# /home/ssenth21/.conda/envs/anomalib_env/lib/python3.8/site-packages/pytorch_lightning/trainer/trainer.py:1609: PossibleUserWarning: The number of training batches (21) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Epoch 0:  88%|████████▊ | 21/24 [00:02<00:00,  7.09it/s, loss=49, v_num=4, train_loss_step=11.60]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 0:  92%|█████████▏| 22/24 [00:03<00:00,  5.60it/s, loss=49, v_num=4, train_loss_step=11.60]
# Epoch 0:  96%|█████████▌| 23/24 [00:04<00:00,  5.58it/s, loss=49, v_num=4, train_loss_step=11.60]
# Epoch 0: 100%|██████████| 24/24 [00:04<00:00,  5.60it/s, loss=49, v_num=4, train_loss_step=11.60, image_AUROC=0.544]
# Epoch 1:  88%|████████▊ | 21/24 [00:02<00:00,  9.20it/s, loss=39.7, v_num=4, train_loss_step=9.210, image_AUROC=0.544, train_loss_epoch=50.90]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 1:  92%|█████████▏| 22/24 [00:03<00:00,  6.61it/s, loss=39.7, v_num=4, train_loss_step=9.210, image_AUROC=0.544, train_loss_epoch=50.90]
# Epoch 1:  96%|█████████▌| 23/24 [00:03<00:00,  6.51it/s, loss=39.7, v_num=4, train_loss_step=9.210, image_AUROC=0.544, train_loss_epoch=50.90]
# Epoch 1: 100%|██████████| 24/24 [00:03<00:00,  6.70it/s, loss=39.7, v_num=4, train_loss_step=9.210, image_AUROC=0.567, train_loss_epoch=50.90]
# Epoch 2:  88%|████████▊ | 21/24 [00:02<00:00,  9.24it/s, loss=31.5, v_num=4, train_loss_step=7.290, image_AUROC=0.567, train_loss_epoch=41.10]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 2:  92%|█████████▏| 22/24 [00:03<00:00,  6.63it/s, loss=31.5, v_num=4, train_loss_step=7.290, image_AUROC=0.567, train_loss_epoch=41.10]
# Epoch 2:  96%|█████████▌| 23/24 [00:03<00:00,  6.50it/s, loss=31.5, v_num=4, train_loss_step=7.290, image_AUROC=0.567, train_loss_epoch=41.10]
# Epoch 2: 100%|██████████| 24/24 [00:03<00:00,  6.69it/s, loss=31.5, v_num=4, train_loss_step=7.290, image_AUROC=0.585, train_loss_epoch=41.10]
# Epoch 3:  88%|████████▊ | 21/24 [00:02<00:00,  8.89it/s, loss=25.2, v_num=4, train_loss_step=5.920, image_AUROC=0.585, train_loss_epoch=32.70]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 3:  92%|█████████▏| 22/24 [00:03<00:00,  6.41it/s, loss=25.2, v_num=4, train_loss_step=5.920, image_AUROC=0.585, train_loss_epoch=32.70]
# Epoch 3:  96%|█████████▌| 23/24 [00:03<00:00,  6.34it/s, loss=25.2, v_num=4, train_loss_step=5.920, image_AUROC=0.585, train_loss_epoch=32.70]
# Epoch 3: 100%|██████████| 24/24 [00:03<00:00,  6.53it/s, loss=25.2, v_num=4, train_loss_step=5.920, image_AUROC=0.610, train_loss_epoch=32.70]
# Epoch 4:  88%|████████▊ | 21/24 [00:02<00:00,  9.15it/s, loss=20.9, v_num=4, train_loss_step=5.570, image_AUROC=0.610, train_loss_epoch=26.10]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 4:  92%|█████████▏| 22/24 [00:03<00:00,  6.57it/s, loss=20.9, v_num=4, train_loss_step=5.570, image_AUROC=0.610, train_loss_epoch=26.10]
# Epoch 4:  96%|█████████▌| 23/24 [00:03<00:00,  6.45it/s, loss=20.9, v_num=4, train_loss_step=5.570, image_AUROC=0.610, train_loss_epoch=26.10]
# Epoch 4: 100%|██████████| 24/24 [00:03<00:00,  6.64it/s, loss=20.9, v_num=4, train_loss_step=5.570, image_AUROC=0.610, train_loss_epoch=26.10]
# Epoch 5:  88%|████████▊ | 21/24 [00:02<00:00,  9.61it/s, loss=18.2, v_num=4, train_loss_step=4.570, image_AUROC=0.610, train_loss_epoch=21.70]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 5:  92%|█████████▏| 22/24 [00:03<00:00,  6.82it/s, loss=18.2, v_num=4, train_loss_step=4.570, image_AUROC=0.610, train_loss_epoch=21.70]
# Epoch 5:  96%|█████████▌| 23/24 [00:03<00:00,  6.68it/s, loss=18.2, v_num=4, train_loss_step=4.570, image_AUROC=0.610, train_loss_epoch=21.70]
# Epoch 5: 100%|██████████| 24/24 [00:03<00:00,  6.88it/s, loss=18.2, v_num=4, train_loss_step=4.570, image_AUROC=0.619, train_loss_epoch=21.70]
# Epoch 6:  88%|████████▊ | 21/24 [00:02<00:00,  9.62it/s, loss=16, v_num=4, train_loss_step=3.980, image_AUROC=0.619, train_loss_epoch=18.90]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 6:  92%|█████████▏| 22/24 [00:03<00:00,  6.75it/s, loss=16, v_num=4, train_loss_step=3.980, image_AUROC=0.619, train_loss_epoch=18.90]
# Epoch 6:  96%|█████████▌| 23/24 [00:03<00:00,  6.66it/s, loss=16, v_num=4, train_loss_step=3.980, image_AUROC=0.619, train_loss_epoch=18.90]
# Epoch 6: 100%|██████████| 24/24 [00:03<00:00,  6.85it/s, loss=16, v_num=4, train_loss_step=3.980, image_AUROC=0.633, train_loss_epoch=18.90]
# Epoch 7:  88%|████████▊ | 21/24 [00:02<00:00,  9.32it/s, loss=14.5, v_num=4, train_loss_step=3.970, image_AUROC=0.633, train_loss_epoch=16.50]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 7:  92%|█████████▏| 22/24 [00:03<00:00,  6.67it/s, loss=14.5, v_num=4, train_loss_step=3.970, image_AUROC=0.633, train_loss_epoch=16.50]
# Epoch 7:  96%|█████████▌| 23/24 [00:03<00:00,  6.52it/s, loss=14.5, v_num=4, train_loss_step=3.970, image_AUROC=0.633, train_loss_epoch=16.50]
# Epoch 7: 100%|██████████| 24/24 [00:03<00:00,  6.69it/s, loss=14.5, v_num=4, train_loss_step=3.970, image_AUROC=0.663, train_loss_epoch=16.50]
# Epoch 8:  88%|████████▊ | 21/24 [00:02<00:00,  9.31it/s, loss=13.4, v_num=4, train_loss_step=3.180, image_AUROC=0.663, train_loss_epoch=15.00]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 8:  92%|█████████▏| 22/24 [00:03<00:00,  6.64it/s, loss=13.4, v_num=4, train_loss_step=3.180, image_AUROC=0.663, train_loss_epoch=15.00]
# Epoch 8:  96%|█████████▌| 23/24 [00:03<00:00,  6.52it/s, loss=13.4, v_num=4, train_loss_step=3.180, image_AUROC=0.663, train_loss_epoch=15.00]
# Epoch 8: 100%|██████████| 24/24 [00:03<00:00,  6.70it/s, loss=13.4, v_num=4, train_loss_step=3.180, image_AUROC=0.675, train_loss_epoch=15.00]
# Epoch 9:  88%|████████▊ | 21/24 [00:02<00:00,  9.13it/s, loss=12.5, v_num=4, train_loss_step=3.250, image_AUROC=0.675, train_loss_epoch=13.80]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 9:  92%|█████████▏| 22/24 [00:03<00:00,  6.44it/s, loss=12.5, v_num=4, train_loss_step=3.250, image_AUROC=0.675, train_loss_epoch=13.80]
# Epoch 9:  96%|█████████▌| 23/24 [00:03<00:00,  6.41it/s, loss=12.5, v_num=4, train_loss_step=3.250, image_AUROC=0.675, train_loss_epoch=13.80]
# Epoch 9: 100%|██████████| 24/24 [00:03<00:00,  6.60it/s, loss=12.5, v_num=4, train_loss_step=3.250, image_AUROC=0.688, train_loss_epoch=13.80]
# Epoch 10:  88%|████████▊ | 21/24 [00:02<00:00,  9.18it/s, loss=11.8, v_num=4, train_loss_step=2.900, image_AUROC=0.688, train_loss_epoch=12.90]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 10:  92%|█████████▏| 22/24 [00:03<00:00,  6.59it/s, loss=11.8, v_num=4, train_loss_step=2.900, image_AUROC=0.688, train_loss_epoch=12.90]
# Epoch 10:  96%|█████████▌| 23/24 [00:03<00:00,  6.48it/s, loss=11.8, v_num=4, train_loss_step=2.900, image_AUROC=0.688, train_loss_epoch=12.90]
# Epoch 10: 100%|██████████| 24/24 [00:03<00:00,  6.67it/s, loss=11.8, v_num=4, train_loss_step=2.900, image_AUROC=0.690, train_loss_epoch=12.90]
# Epoch 11:  88%|████████▊ | 21/24 [00:02<00:00,  9.44it/s, loss=11.1, v_num=4, train_loss_step=2.910, image_AUROC=0.690, train_loss_epoch=12.20]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 11:  92%|█████████▏| 22/24 [00:03<00:00,  6.71it/s, loss=11.1, v_num=4, train_loss_step=2.910, image_AUROC=0.690, train_loss_epoch=12.20]
# Epoch 11:  96%|█████████▌| 23/24 [00:03<00:00,  6.61it/s, loss=11.1, v_num=4, train_loss_step=2.910, image_AUROC=0.690, train_loss_epoch=12.20]
# Epoch 11: 100%|██████████| 24/24 [00:03<00:00,  6.80it/s, loss=11.1, v_num=4, train_loss_step=2.910, image_AUROC=0.685, train_loss_epoch=12.20]
# Epoch 12:  88%|████████▊ | 21/24 [00:02<00:00,  9.32it/s, loss=10.8, v_num=4, train_loss_step=2.700, image_AUROC=0.685, train_loss_epoch=11.40]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 12:  92%|█████████▏| 22/24 [00:03<00:00,  6.67it/s, loss=10.8, v_num=4, train_loss_step=2.700, image_AUROC=0.685, train_loss_epoch=11.40]
# Epoch 12:  96%|█████████▌| 23/24 [00:03<00:00,  6.55it/s, loss=10.8, v_num=4, train_loss_step=2.700, image_AUROC=0.685, train_loss_epoch=11.40]
# Epoch 12: 100%|██████████| 24/24 [00:03<00:00,  6.73it/s, loss=10.8, v_num=4, train_loss_step=2.700, image_AUROC=0.623, train_loss_epoch=11.40]
# Epoch 13:  88%|████████▊ | 21/24 [00:02<00:00,  9.06it/s, loss=10, v_num=4, train_loss_step=2.680, image_AUROC=0.623, train_loss_epoch=11.10]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 13:  92%|█████████▏| 22/24 [00:03<00:00,  6.54it/s, loss=10, v_num=4, train_loss_step=2.680, image_AUROC=0.623, train_loss_epoch=11.10]
# Epoch 13:  96%|█████████▌| 23/24 [00:03<00:00,  6.44it/s, loss=10, v_num=4, train_loss_step=2.680, image_AUROC=0.623, train_loss_epoch=11.10]
# Epoch 13: 100%|██████████| 24/24 [00:03<00:00,  6.63it/s, loss=10, v_num=4, train_loss_step=2.680, image_AUROC=0.579, train_loss_epoch=11.10]
# Epoch 14:  88%|████████▊ | 21/24 [00:02<00:00,  9.08it/s, loss=9.57, v_num=4, train_loss_step=2.370, image_AUROC=0.579, train_loss_epoch=10.30]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 14:  92%|█████████▏| 22/24 [00:03<00:00,  6.52it/s, loss=9.57, v_num=4, train_loss_step=2.370, image_AUROC=0.579, train_loss_epoch=10.30]
# Epoch 14:  96%|█████████▌| 23/24 [00:03<00:00,  6.41it/s, loss=9.57, v_num=4, train_loss_step=2.370, image_AUROC=0.579, train_loss_epoch=10.30]
# Epoch 14: 100%|██████████| 24/24 [00:03<00:00,  6.60it/s, loss=9.57, v_num=4, train_loss_step=2.370, image_AUROC=0.552, train_loss_epoch=10.30]
# Epoch 15:  88%|████████▊ | 21/24 [00:02<00:00,  9.23it/s, loss=9.14, v_num=4, train_loss_step=2.370, image_AUROC=0.552, train_loss_epoch=9.870]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 15:  92%|█████████▏| 22/24 [00:03<00:00,  6.60it/s, loss=9.14, v_num=4, train_loss_step=2.370, image_AUROC=0.552, train_loss_epoch=9.870]
# Epoch 15:  96%|█████████▌| 23/24 [00:03<00:00,  6.47it/s, loss=9.14, v_num=4, train_loss_step=2.370, image_AUROC=0.552, train_loss_epoch=9.870]
# Epoch 15: 100%|██████████| 24/24 [00:03<00:00,  6.66it/s, loss=9.14, v_num=4, train_loss_step=2.370, image_AUROC=0.548, train_loss_epoch=9.870]
# Epoch 16:  88%|████████▊ | 21/24 [00:02<00:00,  9.48it/s, loss=8.94, v_num=4, train_loss_step=2.460, image_AUROC=0.548, train_loss_epoch=9.430]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 16:  92%|█████████▏| 22/24 [00:03<00:00,  6.68it/s, loss=8.94, v_num=4, train_loss_step=2.460, image_AUROC=0.548, train_loss_epoch=9.430]
# Epoch 16:  96%|█████████▌| 23/24 [00:03<00:00,  6.57it/s, loss=8.94, v_num=4, train_loss_step=2.460, image_AUROC=0.548, train_loss_epoch=9.430]
# Epoch 16: 100%|██████████| 24/24 [00:03<00:00,  6.76it/s, loss=8.94, v_num=4, train_loss_step=2.460, image_AUROC=0.569, train_loss_epoch=9.430]
# Epoch 17:  88%|████████▊ | 21/24 [00:02<00:00,  9.16it/s, loss=8.51, v_num=4, train_loss_step=2.150, image_AUROC=0.569, train_loss_epoch=9.220]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 17:  92%|█████████▏| 22/24 [00:03<00:00,  6.57it/s, loss=8.51, v_num=4, train_loss_step=2.150, image_AUROC=0.569, train_loss_epoch=9.220]
# Epoch 17:  96%|█████████▌| 23/24 [00:03<00:00,  6.47it/s, loss=8.51, v_num=4, train_loss_step=2.150, image_AUROC=0.569, train_loss_epoch=9.220]
# Epoch 17: 100%|██████████| 24/24 [00:03<00:00,  6.65it/s, loss=8.51, v_num=4, train_loss_step=2.150, image_AUROC=0.575, train_loss_epoch=9.220]
# Epoch 18:  88%|████████▊ | 21/24 [00:02<00:00,  9.53it/s, loss=8.38, v_num=4, train_loss_step=2.260, image_AUROC=0.575, train_loss_epoch=8.780]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 18:  92%|█████████▏| 22/24 [00:03<00:00,  6.80it/s, loss=8.38, v_num=4, train_loss_step=2.260, image_AUROC=0.575, train_loss_epoch=8.780]
# Epoch 18:  96%|█████████▌| 23/24 [00:03<00:00,  6.68it/s, loss=8.38, v_num=4, train_loss_step=2.260, image_AUROC=0.575, train_loss_epoch=8.780]
# Epoch 18: 100%|██████████| 24/24 [00:03<00:00,  6.86it/s, loss=8.38, v_num=4, train_loss_step=2.260, image_AUROC=0.587, train_loss_epoch=8.780]
# Epoch 19:  88%|████████▊ | 21/24 [00:02<00:00,  9.70it/s, loss=8.02, v_num=4, train_loss_step=2.150, image_AUROC=0.587, train_loss_epoch=8.630]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 19:  92%|█████████▏| 22/24 [00:03<00:00,  6.87it/s, loss=8.02, v_num=4, train_loss_step=2.150, image_AUROC=0.587, train_loss_epoch=8.630]
# Epoch 19:  96%|█████████▌| 23/24 [00:03<00:00,  6.73it/s, loss=8.02, v_num=4, train_loss_step=2.150, image_AUROC=0.587, train_loss_epoch=8.630]
# Epoch 19: 100%|██████████| 24/24 [00:03<00:00,  6.92it/s, loss=8.02, v_num=4, train_loss_step=2.150, image_AUROC=0.587, train_loss_epoch=8.630]
# Epoch 20:  88%|████████▊ | 21/24 [00:02<00:00,  9.46it/s, loss=7.76, v_num=4, train_loss_step=2.020, image_AUROC=0.587, train_loss_epoch=8.280]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 20:  92%|█████████▏| 22/24 [00:03<00:00,  6.73it/s, loss=7.76, v_num=4, train_loss_step=2.020, image_AUROC=0.587, train_loss_epoch=8.280]
# Epoch 20:  96%|█████████▌| 23/24 [00:03<00:00,  6.62it/s, loss=7.76, v_num=4, train_loss_step=2.020, image_AUROC=0.587, train_loss_epoch=8.280]
# Epoch 20: 100%|██████████| 24/24 [00:03<00:00,  6.82it/s, loss=7.76, v_num=4, train_loss_step=2.020, image_AUROC=0.604, train_loss_epoch=8.280]
# Epoch 21:  88%|████████▊ | 21/24 [00:02<00:00,  9.62it/s, loss=7.55, v_num=4, train_loss_step=2.030, image_AUROC=0.604, train_loss_epoch=7.980]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 21:  92%|█████████▏| 22/24 [00:03<00:00,  6.76it/s, loss=7.55, v_num=4, train_loss_step=2.030, image_AUROC=0.604, train_loss_epoch=7.980]
# Epoch 21:  96%|█████████▌| 23/24 [00:03<00:00,  6.65it/s, loss=7.55, v_num=4, train_loss_step=2.030, image_AUROC=0.604, train_loss_epoch=7.980]
# Epoch 21: 100%|██████████| 24/24 [00:03<00:00,  6.83it/s, loss=7.55, v_num=4, train_loss_step=2.030, image_AUROC=0.629, train_loss_epoch=7.980]
# Epoch 22:  88%|████████▊ | 21/24 [00:02<00:00,  9.13it/s, loss=7.49, v_num=4, train_loss_step=1.930, image_AUROC=0.629, train_loss_epoch=7.780]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 22:  92%|█████████▏| 22/24 [00:03<00:00,  6.58it/s, loss=7.49, v_num=4, train_loss_step=1.930, image_AUROC=0.629, train_loss_epoch=7.780]
# Epoch 22:  96%|█████████▌| 23/24 [00:03<00:00,  6.48it/s, loss=7.49, v_num=4, train_loss_step=1.930, image_AUROC=0.629, train_loss_epoch=7.780]
# Epoch 22: 100%|██████████| 24/24 [00:03<00:00,  6.66it/s, loss=7.49, v_num=4, train_loss_step=1.930, image_AUROC=0.625, train_loss_epoch=7.780]
# Epoch 23:  88%|████████▊ | 21/24 [00:02<00:00,  9.23it/s, loss=7.12, v_num=4, train_loss_step=2.100, image_AUROC=0.625, train_loss_epoch=7.730]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 23:  92%|█████████▏| 22/24 [00:03<00:00,  6.58it/s, loss=7.12, v_num=4, train_loss_step=2.100, image_AUROC=0.625, train_loss_epoch=7.730]
# Epoch 23:  96%|█████████▌| 23/24 [00:03<00:00,  6.48it/s, loss=7.12, v_num=4, train_loss_step=2.100, image_AUROC=0.625, train_loss_epoch=7.730]
# Epoch 23: 100%|██████████| 24/24 [00:03<00:00,  6.66it/s, loss=7.12, v_num=4, train_loss_step=2.100, image_AUROC=0.621, train_loss_epoch=7.730]
# Epoch 24:  88%|████████▊ | 21/24 [00:02<00:00,  9.46it/s, loss=7.04, v_num=4, train_loss_step=1.810, image_AUROC=0.621, train_loss_epoch=7.330]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 24:  92%|█████████▏| 22/24 [00:03<00:00,  6.69it/s, loss=7.04, v_num=4, train_loss_step=1.810, image_AUROC=0.621, train_loss_epoch=7.330]
# Epoch 24:  96%|█████████▌| 23/24 [00:03<00:00,  6.60it/s, loss=7.04, v_num=4, train_loss_step=1.810, image_AUROC=0.621, train_loss_epoch=7.330]
# Epoch 24: 100%|██████████| 24/24 [00:03<00:00,  6.78it/s, loss=7.04, v_num=4, train_loss_step=1.810, image_AUROC=0.615, train_loss_epoch=7.330]
# Epoch 25:  88%|████████▊ | 21/24 [00:02<00:00,  9.60it/s, loss=6.97, v_num=4, train_loss_step=1.720, image_AUROC=0.615, train_loss_epoch=7.250]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 25:  92%|█████████▏| 22/24 [00:03<00:00,  6.83it/s, loss=6.97, v_num=4, train_loss_step=1.720, image_AUROC=0.615, train_loss_epoch=7.250]
# Epoch 25:  96%|█████████▌| 23/24 [00:03<00:00,  6.70it/s, loss=6.97, v_num=4, train_loss_step=1.720, image_AUROC=0.615, train_loss_epoch=7.250]
# Epoch 25: 100%|██████████| 24/24 [00:03<00:00,  6.88it/s, loss=6.97, v_num=4, train_loss_step=1.720, image_AUROC=0.640, train_loss_epoch=7.250]
# Epoch 26:  88%|████████▊ | 21/24 [00:02<00:00,  9.50it/s, loss=6.79, v_num=4, train_loss_step=2.080, image_AUROC=0.640, train_loss_epoch=7.180]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 26:  92%|█████████▏| 22/24 [00:03<00:00,  6.70it/s, loss=6.79, v_num=4, train_loss_step=2.080, image_AUROC=0.640, train_loss_epoch=7.180]
# Epoch 26:  96%|█████████▌| 23/24 [00:03<00:00,  6.58it/s, loss=6.79, v_num=4, train_loss_step=2.080, image_AUROC=0.640, train_loss_epoch=7.180]
# Epoch 26: 100%|██████████| 24/24 [00:03<00:00,  6.76it/s, loss=6.79, v_num=4, train_loss_step=2.080, image_AUROC=0.688, train_loss_epoch=7.180]
# Epoch 27:  88%|████████▊ | 21/24 [00:02<00:00,  9.39it/s, loss=6.61, v_num=4, train_loss_step=1.780, image_AUROC=0.688, train_loss_epoch=6.980]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 27:  92%|█████████▏| 22/24 [00:03<00:00,  6.65it/s, loss=6.61, v_num=4, train_loss_step=1.780, image_AUROC=0.688, train_loss_epoch=6.980]
# Epoch 27:  96%|█████████▌| 23/24 [00:03<00:00,  6.52it/s, loss=6.61, v_num=4, train_loss_step=1.780, image_AUROC=0.688, train_loss_epoch=6.980]
# Epoch 27: 100%|██████████| 24/24 [00:03<00:00,  6.71it/s, loss=6.61, v_num=4, train_loss_step=1.780, image_AUROC=0.654, train_loss_epoch=6.980]
# Epoch 28:  88%|████████▊ | 21/24 [00:02<00:00,  9.29it/s, loss=6.43, v_num=4, train_loss_step=1.720, image_AUROC=0.654, train_loss_epoch=6.820]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 28:  92%|█████████▏| 22/24 [00:03<00:00,  6.63it/s, loss=6.43, v_num=4, train_loss_step=1.720, image_AUROC=0.654, train_loss_epoch=6.820]
# Epoch 28:  96%|█████████▌| 23/24 [00:03<00:00,  6.50it/s, loss=6.43, v_num=4, train_loss_step=1.720, image_AUROC=0.654, train_loss_epoch=6.820]
# Epoch 28: 100%|██████████| 24/24 [00:03<00:00,  6.68it/s, loss=6.43, v_num=4, train_loss_step=1.720, image_AUROC=0.679, train_loss_epoch=6.820]
# Epoch 29:  88%|████████▊ | 21/24 [00:02<00:00,  9.46it/s, loss=6.36, v_num=4, train_loss_step=1.620, image_AUROC=0.679, train_loss_epoch=6.640]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 29:  92%|█████████▏| 22/24 [00:03<00:00,  6.71it/s, loss=6.36, v_num=4, train_loss_step=1.620, image_AUROC=0.679, train_loss_epoch=6.640]
# Epoch 29:  96%|█████████▌| 23/24 [00:03<00:00,  6.58it/s, loss=6.36, v_num=4, train_loss_step=1.620, image_AUROC=0.679, train_loss_epoch=6.640]
# Epoch 29: 100%|██████████| 24/24 [00:03<00:00,  6.77it/s, loss=6.36, v_num=4, train_loss_step=1.620, image_AUROC=0.688, train_loss_epoch=6.640]
# Epoch 30:  88%|████████▊ | 21/24 [00:02<00:00,  9.19it/s, loss=6.32, v_num=4, train_loss_step=1.720, image_AUROC=0.688, train_loss_epoch=6.560]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 30:  92%|█████████▏| 22/24 [00:03<00:00,  6.59it/s, loss=6.32, v_num=4, train_loss_step=1.720, image_AUROC=0.688, train_loss_epoch=6.560]
# Epoch 30:  96%|█████████▌| 23/24 [00:03<00:00,  6.45it/s, loss=6.32, v_num=4, train_loss_step=1.720, image_AUROC=0.688, train_loss_epoch=6.560]
# Epoch 30: 100%|██████████| 24/24 [00:03<00:00,  6.64it/s, loss=6.32, v_num=4, train_loss_step=1.720, image_AUROC=0.673, train_loss_epoch=6.560]
# Epoch 31:  88%|████████▊ | 21/24 [00:02<00:00,  9.47it/s, loss=6.25, v_num=4, train_loss_step=1.590, image_AUROC=0.673, train_loss_epoch=6.510]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 31:  92%|█████████▏| 22/24 [00:03<00:00,  6.67it/s, loss=6.25, v_num=4, train_loss_step=1.590, image_AUROC=0.673, train_loss_epoch=6.510]
# Epoch 31:  96%|█████████▌| 23/24 [00:03<00:00,  6.57it/s, loss=6.25, v_num=4, train_loss_step=1.590, image_AUROC=0.673, train_loss_epoch=6.510]
# Epoch 31: 100%|██████████| 24/24 [00:03<00:00,  6.75it/s, loss=6.25, v_num=4, train_loss_step=1.590, image_AUROC=0.694, train_loss_epoch=6.510]
# Epoch 32:  88%|████████▊ | 21/24 [00:02<00:00,  9.14it/s, loss=5.99, v_num=4, train_loss_step=1.600, image_AUROC=0.694, train_loss_epoch=6.440]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 32:  92%|█████████▏| 22/24 [00:03<00:00,  6.57it/s, loss=5.99, v_num=4, train_loss_step=1.600, image_AUROC=0.694, train_loss_epoch=6.440]
# Epoch 32:  96%|█████████▌| 23/24 [00:03<00:00,  6.45it/s, loss=5.99, v_num=4, train_loss_step=1.600, image_AUROC=0.694, train_loss_epoch=6.440]
# Epoch 32: 100%|██████████| 24/24 [00:03<00:00,  6.63it/s, loss=5.99, v_num=4, train_loss_step=1.600, image_AUROC=0.696, train_loss_epoch=6.440]
# Epoch 33:  88%|████████▊ | 21/24 [00:02<00:00,  9.67it/s, loss=5.95, v_num=4, train_loss_step=1.590, image_AUROC=0.696, train_loss_epoch=6.180]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 33:  92%|█████████▏| 22/24 [00:03<00:00,  6.84it/s, loss=5.95, v_num=4, train_loss_step=1.590, image_AUROC=0.696, train_loss_epoch=6.180]
# Epoch 33:  96%|█████████▌| 23/24 [00:03<00:00,  6.71it/s, loss=5.95, v_num=4, train_loss_step=1.590, image_AUROC=0.696, train_loss_epoch=6.180]
# Epoch 33: 100%|██████████| 24/24 [00:03<00:00,  6.90it/s, loss=5.95, v_num=4, train_loss_step=1.590, image_AUROC=0.700, train_loss_epoch=6.180]
# Epoch 34:  88%|████████▊ | 21/24 [00:02<00:00,  9.36it/s, loss=5.9, v_num=4, train_loss_step=1.500, image_AUROC=0.700, train_loss_epoch=6.120]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 34:  92%|█████████▏| 22/24 [00:03<00:00,  6.65it/s, loss=5.9, v_num=4, train_loss_step=1.500, image_AUROC=0.700, train_loss_epoch=6.120]
# Epoch 34:  96%|█████████▌| 23/24 [00:03<00:00,  6.54it/s, loss=5.9, v_num=4, train_loss_step=1.500, image_AUROC=0.700, train_loss_epoch=6.120]
# Epoch 34: 100%|██████████| 24/24 [00:03<00:00,  6.71it/s, loss=5.9, v_num=4, train_loss_step=1.500, image_AUROC=0.681, train_loss_epoch=6.120]
# Epoch 35:  88%|████████▊ | 21/24 [00:02<00:00,  9.47it/s, loss=5.75, v_num=4, train_loss_step=1.500, image_AUROC=0.681, train_loss_epoch=6.070]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 35:  92%|█████████▏| 22/24 [00:03<00:00,  6.77it/s, loss=5.75, v_num=4, train_loss_step=1.500, image_AUROC=0.681, train_loss_epoch=6.070]
# Epoch 35:  96%|█████████▌| 23/24 [00:03<00:00,  6.66it/s, loss=5.75, v_num=4, train_loss_step=1.500, image_AUROC=0.681, train_loss_epoch=6.070]
# Epoch 35: 100%|██████████| 24/24 [00:03<00:00,  6.85it/s, loss=5.75, v_num=4, train_loss_step=1.500, image_AUROC=0.694, train_loss_epoch=6.070]
# Epoch 36:  88%|████████▊ | 21/24 [00:02<00:00,  9.34it/s, loss=5.66, v_num=4, train_loss_step=1.590, image_AUROC=0.694, train_loss_epoch=5.930]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 36:  92%|█████████▏| 22/24 [00:03<00:00,  6.64it/s, loss=5.66, v_num=4, train_loss_step=1.590, image_AUROC=0.694, train_loss_epoch=5.930]
# Epoch 36:  96%|█████████▌| 23/24 [00:03<00:00,  6.54it/s, loss=5.66, v_num=4, train_loss_step=1.590, image_AUROC=0.694, train_loss_epoch=5.930]
# Epoch 36: 100%|██████████| 24/24 [00:03<00:00,  6.72it/s, loss=5.66, v_num=4, train_loss_step=1.590, image_AUROC=0.704, train_loss_epoch=5.930]
# Epoch 37:  88%|████████▊ | 21/24 [00:02<00:00,  9.24it/s, loss=5.58, v_num=4, train_loss_step=1.610, image_AUROC=0.704, train_loss_epoch=5.850]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 37:  92%|█████████▏| 22/24 [00:03<00:00,  6.60it/s, loss=5.58, v_num=4, train_loss_step=1.610, image_AUROC=0.704, train_loss_epoch=5.850]
# Epoch 37:  96%|█████████▌| 23/24 [00:03<00:00,  6.50it/s, loss=5.58, v_num=4, train_loss_step=1.610, image_AUROC=0.704, train_loss_epoch=5.850]
# Epoch 37: 100%|██████████| 24/24 [00:03<00:00,  6.68it/s, loss=5.58, v_num=4, train_loss_step=1.610, image_AUROC=0.696, train_loss_epoch=5.850]
# Epoch 38:  88%|████████▊ | 21/24 [00:02<00:00,  9.31it/s, loss=5.53, v_num=4, train_loss_step=1.470, image_AUROC=0.696, train_loss_epoch=5.740]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 38:  92%|█████████▏| 22/24 [00:03<00:00,  6.63it/s, loss=5.53, v_num=4, train_loss_step=1.470, image_AUROC=0.696, train_loss_epoch=5.740]
# Epoch 38:  96%|█████████▌| 23/24 [00:03<00:00,  6.52it/s, loss=5.53, v_num=4, train_loss_step=1.470, image_AUROC=0.696, train_loss_epoch=5.740]
# Epoch 38: 100%|██████████| 24/24 [00:03<00:00,  6.70it/s, loss=5.53, v_num=4, train_loss_step=1.470, image_AUROC=0.577, train_loss_epoch=5.740]
# Epoch 39:  88%|████████▊ | 21/24 [00:02<00:00,  9.01it/s, loss=5.46, v_num=4, train_loss_step=1.530, image_AUROC=0.577, train_loss_epoch=5.690]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 39:  92%|█████████▏| 22/24 [00:03<00:00,  6.51it/s, loss=5.46, v_num=4, train_loss_step=1.530, image_AUROC=0.577, train_loss_epoch=5.690]
# Epoch 39:  96%|█████████▌| 23/24 [00:03<00:00,  6.39it/s, loss=5.46, v_num=4, train_loss_step=1.530, image_AUROC=0.577, train_loss_epoch=5.690]
# Epoch 39: 100%|██████████| 24/24 [00:03<00:00,  6.57it/s, loss=5.46, v_num=4, train_loss_step=1.530, image_AUROC=0.690, train_loss_epoch=5.690]
# Epoch 40:  88%|████████▊ | 21/24 [00:02<00:00,  9.43it/s, loss=5.33, v_num=4, train_loss_step=1.480, image_AUROC=0.690, train_loss_epoch=5.620]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 40:  92%|█████████▏| 22/24 [00:03<00:00,  6.71it/s, loss=5.33, v_num=4, train_loss_step=1.480, image_AUROC=0.690, train_loss_epoch=5.620]
# Epoch 40:  96%|█████████▌| 23/24 [00:03<00:00,  6.59it/s, loss=5.33, v_num=4, train_loss_step=1.480, image_AUROC=0.690, train_loss_epoch=5.620]
# Epoch 40: 100%|██████████| 24/24 [00:03<00:00,  6.77it/s, loss=5.33, v_num=4, train_loss_step=1.480, image_AUROC=0.698, train_loss_epoch=5.620]
# Epoch 41:  88%|████████▊ | 21/24 [00:02<00:00,  9.69it/s, loss=5.42, v_num=4, train_loss_step=1.480, image_AUROC=0.698, train_loss_epoch=5.480]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 41:  92%|█████████▏| 22/24 [00:03<00:00,  6.75it/s, loss=5.42, v_num=4, train_loss_step=1.480, image_AUROC=0.698, train_loss_epoch=5.480]
# Epoch 41:  96%|█████████▌| 23/24 [00:03<00:00,  6.66it/s, loss=5.42, v_num=4, train_loss_step=1.480, image_AUROC=0.698, train_loss_epoch=5.480]
# Epoch 41: 100%|██████████| 24/24 [00:03<00:00,  6.85it/s, loss=5.42, v_num=4, train_loss_step=1.480, image_AUROC=0.706, train_loss_epoch=5.480]
# Epoch 42:  88%|████████▊ | 21/24 [00:02<00:00,  9.45it/s, loss=5.24, v_num=4, train_loss_step=1.410, image_AUROC=0.706, train_loss_epoch=5.580]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 42:  92%|█████████▏| 22/24 [00:03<00:00,  6.71it/s, loss=5.24, v_num=4, train_loss_step=1.410, image_AUROC=0.706, train_loss_epoch=5.580]
# Epoch 42:  96%|█████████▌| 23/24 [00:03<00:00,  6.58it/s, loss=5.24, v_num=4, train_loss_step=1.410, image_AUROC=0.706, train_loss_epoch=5.580]
# Epoch 42: 100%|██████████| 24/24 [00:03<00:00,  6.76it/s, loss=5.24, v_num=4, train_loss_step=1.410, image_AUROC=0.715, train_loss_epoch=5.580]
# Epoch 43:  88%|████████▊ | 21/24 [00:02<00:00,  9.49it/s, loss=5.2, v_num=4, train_loss_step=1.370, image_AUROC=0.715, train_loss_epoch=5.390]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 43:  92%|█████████▏| 22/24 [00:03<00:00,  6.72it/s, loss=5.2, v_num=4, train_loss_step=1.370, image_AUROC=0.715, train_loss_epoch=5.390]
# Epoch 43:  96%|█████████▌| 23/24 [00:03<00:00,  6.57it/s, loss=5.2, v_num=4, train_loss_step=1.370, image_AUROC=0.715, train_loss_epoch=5.390]
# Epoch 43: 100%|██████████| 24/24 [00:03<00:00,  6.76it/s, loss=5.2, v_num=4, train_loss_step=1.370, image_AUROC=0.719, train_loss_epoch=5.390]
# Epoch 44:  88%|████████▊ | 21/24 [00:02<00:00,  9.36it/s, loss=5.11, v_num=4, train_loss_step=1.260, image_AUROC=0.719, train_loss_epoch=5.360]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 44:  92%|█████████▏| 22/24 [00:03<00:00,  6.67it/s, loss=5.11, v_num=4, train_loss_step=1.260, image_AUROC=0.719, train_loss_epoch=5.360]
# Epoch 44:  96%|█████████▌| 23/24 [00:03<00:00,  6.58it/s, loss=5.11, v_num=4, train_loss_step=1.260, image_AUROC=0.719, train_loss_epoch=5.360]
# Epoch 44: 100%|██████████| 24/24 [00:03<00:00,  6.76it/s, loss=5.11, v_num=4, train_loss_step=1.260, image_AUROC=0.723, train_loss_epoch=5.360]
# Epoch 45:  88%|████████▊ | 21/24 [00:02<00:00,  9.47it/s, loss=5.06, v_num=4, train_loss_step=1.590, image_AUROC=0.723, train_loss_epoch=5.270]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 45:  92%|█████████▏| 22/24 [00:03<00:00,  6.71it/s, loss=5.06, v_num=4, train_loss_step=1.590, image_AUROC=0.723, train_loss_epoch=5.270]
# Epoch 45:  96%|█████████▌| 23/24 [00:03<00:00,  6.62it/s, loss=5.06, v_num=4, train_loss_step=1.590, image_AUROC=0.723, train_loss_epoch=5.270]
# Epoch 45: 100%|██████████| 24/24 [00:03<00:00,  6.81it/s, loss=5.06, v_num=4, train_loss_step=1.590, image_AUROC=0.717, train_loss_epoch=5.270]
# Epoch 46:  88%|████████▊ | 21/24 [00:02<00:00,  9.32it/s, loss=4.95, v_num=4, train_loss_step=1.330, image_AUROC=0.717, train_loss_epoch=5.210]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 46:  92%|█████████▏| 22/24 [00:03<00:00,  6.67it/s, loss=4.95, v_num=4, train_loss_step=1.330, image_AUROC=0.717, train_loss_epoch=5.210]
# Epoch 46:  96%|█████████▌| 23/24 [00:03<00:00,  6.54it/s, loss=4.95, v_num=4, train_loss_step=1.330, image_AUROC=0.717, train_loss_epoch=5.210]
# Epoch 46: 100%|██████████| 24/24 [00:03<00:00,  6.72it/s, loss=4.95, v_num=4, train_loss_step=1.330, image_AUROC=0.723, train_loss_epoch=5.210]
# Epoch 47:  88%|████████▊ | 21/24 [00:02<00:00,  9.23it/s, loss=4.91, v_num=4, train_loss_step=1.480, image_AUROC=0.723, train_loss_epoch=5.100]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 47:  92%|█████████▏| 22/24 [00:03<00:00,  6.54it/s, loss=4.91, v_num=4, train_loss_step=1.480, image_AUROC=0.723, train_loss_epoch=5.100]
# Epoch 47:  96%|█████████▌| 23/24 [00:03<00:00,  6.47it/s, loss=4.91, v_num=4, train_loss_step=1.480, image_AUROC=0.723, train_loss_epoch=5.100]
# Epoch 47: 100%|██████████| 24/24 [00:03<00:00,  6.65it/s, loss=4.91, v_num=4, train_loss_step=1.480, image_AUROC=0.702, train_loss_epoch=5.100]
# Epoch 48:  88%|████████▊ | 21/24 [00:02<00:00,  9.58it/s, loss=4.89, v_num=4, train_loss_step=1.320, image_AUROC=0.702, train_loss_epoch=5.050]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 48:  92%|█████████▏| 22/24 [00:03<00:00,  6.74it/s, loss=4.89, v_num=4, train_loss_step=1.320, image_AUROC=0.702, train_loss_epoch=5.050]
# Epoch 48:  96%|█████████▌| 23/24 [00:03<00:00,  6.60it/s, loss=4.89, v_num=4, train_loss_step=1.320, image_AUROC=0.702, train_loss_epoch=5.050]
# Epoch 48: 100%|██████████| 24/24 [00:03<00:00,  6.79it/s, loss=4.89, v_num=4, train_loss_step=1.320, image_AUROC=0.694, train_loss_epoch=5.050]
# Epoch 49:  88%|████████▊ | 21/24 [00:02<00:00,  9.32it/s, loss=4.92, v_num=4, train_loss_step=1.340, image_AUROC=0.694, train_loss_epoch=5.040]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 49:  92%|█████████▏| 22/24 [00:03<00:00,  6.62it/s, loss=4.92, v_num=4, train_loss_step=1.340, image_AUROC=0.694, train_loss_epoch=5.040]
# Epoch 49:  96%|█████████▌| 23/24 [00:03<00:00,  6.51it/s, loss=4.92, v_num=4, train_loss_step=1.340, image_AUROC=0.694, train_loss_epoch=5.040]
# Epoch 49: 100%|██████████| 24/24 [00:03<00:00,  6.69it/s, loss=4.92, v_num=4, train_loss_step=1.340, image_AUROC=0.727, train_loss_epoch=5.040]
# Epoch 50:  88%|████████▊ | 21/24 [00:02<00:00,  9.50it/s, loss=4.87, v_num=4, train_loss_step=1.320, image_AUROC=0.727, train_loss_epoch=5.070]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 50:  92%|█████████▏| 22/24 [00:03<00:00,  6.75it/s, loss=4.87, v_num=4, train_loss_step=1.320, image_AUROC=0.727, train_loss_epoch=5.070]
# Epoch 50:  96%|█████████▌| 23/24 [00:03<00:00,  6.62it/s, loss=4.87, v_num=4, train_loss_step=1.320, image_AUROC=0.727, train_loss_epoch=5.070]
# Epoch 50: 100%|██████████| 24/24 [00:03<00:00,  6.80it/s, loss=4.87, v_num=4, train_loss_step=1.320, image_AUROC=0.704, train_loss_epoch=5.070]
# Epoch 51:  88%|████████▊ | 21/24 [00:02<00:00,  9.41it/s, loss=4.81, v_num=4, train_loss_step=1.380, image_AUROC=0.704, train_loss_epoch=5.010]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 51:  92%|█████████▏| 22/24 [00:03<00:00,  6.66it/s, loss=4.81, v_num=4, train_loss_step=1.380, image_AUROC=0.704, train_loss_epoch=5.010]
# Epoch 51:  96%|█████████▌| 23/24 [00:03<00:00,  6.56it/s, loss=4.81, v_num=4, train_loss_step=1.380, image_AUROC=0.704, train_loss_epoch=5.010]
# Epoch 51: 100%|██████████| 24/24 [00:03<00:00,  6.75it/s, loss=4.81, v_num=4, train_loss_step=1.380, image_AUROC=0.702, train_loss_epoch=5.010]
# Epoch 52:  88%|████████▊ | 21/24 [00:02<00:00,  9.42it/s, loss=4.75, v_num=4, train_loss_step=1.190, image_AUROC=0.702, train_loss_epoch=4.960]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 52:  92%|█████████▏| 22/24 [00:03<00:00,  6.73it/s, loss=4.75, v_num=4, train_loss_step=1.190, image_AUROC=0.702, train_loss_epoch=4.960]
# Epoch 52:  96%|█████████▌| 23/24 [00:03<00:00,  6.61it/s, loss=4.75, v_num=4, train_loss_step=1.190, image_AUROC=0.702, train_loss_epoch=4.960]
# Epoch 52: 100%|██████████| 24/24 [00:03<00:00,  6.80it/s, loss=4.75, v_num=4, train_loss_step=1.190, image_AUROC=0.702, train_loss_epoch=4.960]
# Epoch 53:  88%|████████▊ | 21/24 [00:02<00:00,  8.76it/s, loss=4.72, v_num=4, train_loss_step=1.230, image_AUROC=0.702, train_loss_epoch=4.900]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 53:  92%|█████████▏| 22/24 [00:03<00:00,  6.40it/s, loss=4.72, v_num=4, train_loss_step=1.230, image_AUROC=0.702, train_loss_epoch=4.900]
# Epoch 53:  96%|█████████▌| 23/24 [00:03<00:00,  6.30it/s, loss=4.72, v_num=4, train_loss_step=1.230, image_AUROC=0.702, train_loss_epoch=4.900]
# Epoch 53: 100%|██████████| 24/24 [00:03<00:00,  6.48it/s, loss=4.72, v_num=4, train_loss_step=1.230, image_AUROC=0.702, train_loss_epoch=4.900]
# Epoch 54:  88%|████████▊ | 21/24 [00:02<00:00,  8.93it/s, loss=4.6, v_num=4, train_loss_step=1.220, image_AUROC=0.702, train_loss_epoch=4.860]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 54:  92%|█████████▏| 22/24 [00:03<00:00,  6.47it/s, loss=4.6, v_num=4, train_loss_step=1.220, image_AUROC=0.702, train_loss_epoch=4.860]
# Epoch 54:  96%|█████████▌| 23/24 [00:03<00:00,  6.37it/s, loss=4.6, v_num=4, train_loss_step=1.220, image_AUROC=0.702, train_loss_epoch=4.860]
# Epoch 54: 100%|██████████| 24/24 [00:03<00:00,  6.55it/s, loss=4.6, v_num=4, train_loss_step=1.220, image_AUROC=0.694, train_loss_epoch=4.860]
# Epoch 55:  88%|████████▊ | 21/24 [00:02<00:00,  9.11it/s, loss=4.5, v_num=4, train_loss_step=1.130, image_AUROC=0.694, train_loss_epoch=4.750]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 55:  92%|█████████▏| 22/24 [00:03<00:00,  6.54it/s, loss=4.5, v_num=4, train_loss_step=1.130, image_AUROC=0.694, train_loss_epoch=4.750]
# Epoch 55:  96%|█████████▌| 23/24 [00:03<00:00,  6.41it/s, loss=4.5, v_num=4, train_loss_step=1.130, image_AUROC=0.694, train_loss_epoch=4.750]
# Epoch 55: 100%|██████████| 24/24 [00:03<00:00,  6.59it/s, loss=4.5, v_num=4, train_loss_step=1.130, image_AUROC=0.696, train_loss_epoch=4.750]
# Epoch 56:  88%|████████▊ | 21/24 [00:02<00:00,  9.55it/s, loss=4.49, v_num=4, train_loss_step=1.260, image_AUROC=0.696, train_loss_epoch=4.640]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 56:  92%|█████████▏| 22/24 [00:03<00:00,  6.76it/s, loss=4.49, v_num=4, train_loss_step=1.260, image_AUROC=0.696, train_loss_epoch=4.640]
# Epoch 56:  96%|█████████▌| 23/24 [00:03<00:00,  6.63it/s, loss=4.49, v_num=4, train_loss_step=1.260, image_AUROC=0.696, train_loss_epoch=4.640]
# Epoch 56: 100%|██████████| 24/24 [00:03<00:00,  6.82it/s, loss=4.49, v_num=4, train_loss_step=1.260, image_AUROC=0.671, train_loss_epoch=4.640]
# Epoch 57:  88%|████████▊ | 21/24 [00:02<00:00,  9.16it/s, loss=4.49, v_num=4, train_loss_step=1.260, image_AUROC=0.671, train_loss_epoch=4.610]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 57:  92%|█████████▏| 22/24 [00:03<00:00,  6.55it/s, loss=4.49, v_num=4, train_loss_step=1.260, image_AUROC=0.671, train_loss_epoch=4.610]
# Epoch 57:  96%|█████████▌| 23/24 [00:03<00:00,  6.44it/s, loss=4.49, v_num=4, train_loss_step=1.260, image_AUROC=0.671, train_loss_epoch=4.610]
# Epoch 57: 100%|██████████| 24/24 [00:03<00:00,  6.62it/s, loss=4.49, v_num=4, train_loss_step=1.260, image_AUROC=0.700, train_loss_epoch=4.610]
# Epoch 58:  88%|████████▊ | 21/24 [00:02<00:00,  9.11it/s, loss=4.46, v_num=4, train_loss_step=1.230, image_AUROC=0.700, train_loss_epoch=4.620]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 58:  92%|█████████▏| 22/24 [00:03<00:00,  6.51it/s, loss=4.46, v_num=4, train_loss_step=1.230, image_AUROC=0.700, train_loss_epoch=4.620]
# Epoch 58:  96%|█████████▌| 23/24 [00:03<00:00,  6.41it/s, loss=4.46, v_num=4, train_loss_step=1.230, image_AUROC=0.700, train_loss_epoch=4.620]
# Epoch 58: 100%|██████████| 24/24 [00:03<00:00,  6.60it/s, loss=4.46, v_num=4, train_loss_step=1.230, image_AUROC=0.692, train_loss_epoch=4.620]
# Epoch 59:  88%|████████▊ | 21/24 [00:02<00:00,  9.30it/s, loss=4.41, v_num=4, train_loss_step=1.230, image_AUROC=0.692, train_loss_epoch=4.590]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 59:  92%|█████████▏| 22/24 [00:03<00:00,  6.67it/s, loss=4.41, v_num=4, train_loss_step=1.230, image_AUROC=0.692, train_loss_epoch=4.590]
# Epoch 59:  96%|█████████▌| 23/24 [00:03<00:00,  6.54it/s, loss=4.41, v_num=4, train_loss_step=1.230, image_AUROC=0.692, train_loss_epoch=4.590]
# Epoch 59: 100%|██████████| 24/24 [00:03<00:00,  6.72it/s, loss=4.41, v_num=4, train_loss_step=1.230, image_AUROC=0.660, train_loss_epoch=4.590]
# Epoch 60:  88%|████████▊ | 21/24 [00:02<00:00,  9.26it/s, loss=4.41, v_num=4, train_loss_step=1.230, image_AUROC=0.660, train_loss_epoch=4.540]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 60:  92%|█████████▏| 22/24 [00:03<00:00,  6.60it/s, loss=4.41, v_num=4, train_loss_step=1.230, image_AUROC=0.660, train_loss_epoch=4.540]
# Epoch 60:  96%|█████████▌| 23/24 [00:03<00:00,  6.50it/s, loss=4.41, v_num=4, train_loss_step=1.230, image_AUROC=0.660, train_loss_epoch=4.540]
# Epoch 60: 100%|██████████| 24/24 [00:03<00:00,  6.67it/s, loss=4.41, v_num=4, train_loss_step=1.230, image_AUROC=0.696, train_loss_epoch=4.540]
# Epoch 61:  88%|████████▊ | 21/24 [00:02<00:00,  9.47it/s, loss=4.36, v_num=4, train_loss_step=1.110, image_AUROC=0.696, train_loss_epoch=4.540]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 61:  92%|█████████▏| 22/24 [00:03<00:00,  6.75it/s, loss=4.36, v_num=4, train_loss_step=1.110, image_AUROC=0.696, train_loss_epoch=4.540]
# Epoch 61:  96%|█████████▌| 23/24 [00:03<00:00,  6.64it/s, loss=4.36, v_num=4, train_loss_step=1.110, image_AUROC=0.696, train_loss_epoch=4.540]
# Epoch 61: 100%|██████████| 24/24 [00:03<00:00,  6.83it/s, loss=4.36, v_num=4, train_loss_step=1.110, image_AUROC=0.688, train_loss_epoch=4.540]
# Epoch 62:  88%|████████▊ | 21/24 [00:02<00:00,  9.14it/s, loss=4.29, v_num=4, train_loss_step=1.210, image_AUROC=0.688, train_loss_epoch=4.490]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 62:  92%|█████████▏| 22/24 [00:03<00:00,  6.55it/s, loss=4.29, v_num=4, train_loss_step=1.210, image_AUROC=0.688, train_loss_epoch=4.490]
# Epoch 62:  96%|█████████▌| 23/24 [00:03<00:00,  6.44it/s, loss=4.29, v_num=4, train_loss_step=1.210, image_AUROC=0.688, train_loss_epoch=4.490]
# Epoch 62: 100%|██████████| 24/24 [00:03<00:00,  6.62it/s, loss=4.29, v_num=4, train_loss_step=1.210, image_AUROC=0.700, train_loss_epoch=4.490]
# Epoch 63:  88%|████████▊ | 21/24 [00:02<00:00,  9.51it/s, loss=4.3, v_num=4, train_loss_step=1.190, image_AUROC=0.700, train_loss_epoch=4.420]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 63:  92%|█████████▏| 22/24 [00:03<00:00,  6.77it/s, loss=4.3, v_num=4, train_loss_step=1.190, image_AUROC=0.700, train_loss_epoch=4.420]
# Epoch 63:  96%|█████████▌| 23/24 [00:03<00:00,  6.66it/s, loss=4.3, v_num=4, train_loss_step=1.190, image_AUROC=0.700, train_loss_epoch=4.420]
# Epoch 63: 100%|██████████| 24/24 [00:03<00:00,  6.84it/s, loss=4.3, v_num=4, train_loss_step=1.190, image_AUROC=0.677, train_loss_epoch=4.420]
# Epoch 64:  88%|████████▊ | 21/24 [00:02<00:00,  9.25it/s, loss=4.23, v_num=4, train_loss_step=1.120, image_AUROC=0.677, train_loss_epoch=4.430]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 64:  92%|█████████▏| 22/24 [00:03<00:00,  6.63it/s, loss=4.23, v_num=4, train_loss_step=1.120, image_AUROC=0.677, train_loss_epoch=4.430]
# Epoch 64:  96%|█████████▌| 23/24 [00:03<00:00,  6.51it/s, loss=4.23, v_num=4, train_loss_step=1.120, image_AUROC=0.677, train_loss_epoch=4.430]
# Epoch 64: 100%|██████████| 24/24 [00:03<00:00,  6.70it/s, loss=4.23, v_num=4, train_loss_step=1.120, image_AUROC=0.685, train_loss_epoch=4.430]
# Epoch 65:  88%|████████▊ | 21/24 [00:02<00:00,  9.18it/s, loss=4.14, v_num=4, train_loss_step=1.220, image_AUROC=0.685, train_loss_epoch=4.350]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 65:  92%|█████████▏| 22/24 [00:03<00:00,  6.60it/s, loss=4.14, v_num=4, train_loss_step=1.220, image_AUROC=0.685, train_loss_epoch=4.350]
# Epoch 65:  96%|█████████▌| 23/24 [00:03<00:00,  6.50it/s, loss=4.14, v_num=4, train_loss_step=1.220, image_AUROC=0.685, train_loss_epoch=4.350]
# Epoch 65: 100%|██████████| 24/24 [00:03<00:00,  6.69it/s, loss=4.14, v_num=4, train_loss_step=1.220, image_AUROC=0.690, train_loss_epoch=4.350]
# Epoch 66:  88%|████████▊ | 21/24 [00:02<00:00,  8.86it/s, loss=4.14, v_num=4, train_loss_step=1.130, image_AUROC=0.690, train_loss_epoch=4.260]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 66:  92%|█████████▏| 22/24 [00:03<00:00,  6.40it/s, loss=4.14, v_num=4, train_loss_step=1.130, image_AUROC=0.690, train_loss_epoch=4.260]
# Epoch 66:  96%|█████████▌| 23/24 [00:03<00:00,  6.29it/s, loss=4.14, v_num=4, train_loss_step=1.130, image_AUROC=0.690, train_loss_epoch=4.260]
# Epoch 66: 100%|██████████| 24/24 [00:03<00:00,  6.47it/s, loss=4.14, v_num=4, train_loss_step=1.130, image_AUROC=0.679, train_loss_epoch=4.260]
# Epoch 67:  88%|████████▊ | 21/24 [00:02<00:00,  8.94it/s, loss=4.09, v_num=4, train_loss_step=1.130, image_AUROC=0.679, train_loss_epoch=4.270]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 67:  92%|█████████▏| 22/24 [00:03<00:00,  6.41it/s, loss=4.09, v_num=4, train_loss_step=1.130, image_AUROC=0.679, train_loss_epoch=4.270]
# Epoch 67:  96%|█████████▌| 23/24 [00:03<00:00,  6.31it/s, loss=4.09, v_num=4, train_loss_step=1.130, image_AUROC=0.679, train_loss_epoch=4.270]
# Epoch 67: 100%|██████████| 24/24 [00:03<00:00,  6.49it/s, loss=4.09, v_num=4, train_loss_step=1.130, image_AUROC=0.681, train_loss_epoch=4.270]
# Epoch 68:  88%|████████▊ | 21/24 [00:02<00:00,  9.14it/s, loss=4.07, v_num=4, train_loss_step=1.160, image_AUROC=0.681, train_loss_epoch=4.210]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 68:  92%|█████████▏| 22/24 [00:03<00:00,  6.57it/s, loss=4.07, v_num=4, train_loss_step=1.160, image_AUROC=0.681, train_loss_epoch=4.210]
# Epoch 68:  96%|█████████▌| 23/24 [00:03<00:00,  6.46it/s, loss=4.07, v_num=4, train_loss_step=1.160, image_AUROC=0.681, train_loss_epoch=4.210]
# Epoch 68: 100%|██████████| 24/24 [00:03<00:00,  6.65it/s, loss=4.07, v_num=4, train_loss_step=1.160, image_AUROC=0.658, train_loss_epoch=4.210]
# Epoch 69:  88%|████████▊ | 21/24 [00:02<00:00,  9.42it/s, loss=4.06, v_num=4, train_loss_step=0.990, image_AUROC=0.658, train_loss_epoch=4.190]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 69:  92%|█████████▏| 22/24 [00:03<00:00,  6.70it/s, loss=4.06, v_num=4, train_loss_step=0.990, image_AUROC=0.658, train_loss_epoch=4.190]
# Epoch 69:  96%|█████████▌| 23/24 [00:03<00:00,  6.59it/s, loss=4.06, v_num=4, train_loss_step=0.990, image_AUROC=0.658, train_loss_epoch=4.190]
# Epoch 69: 100%|██████████| 24/24 [00:03<00:00,  6.77it/s, loss=4.06, v_num=4, train_loss_step=0.990, image_AUROC=0.671, train_loss_epoch=4.190]
# Epoch 70:  88%|████████▊ | 21/24 [00:02<00:00,  8.90it/s, loss=4.05, v_num=4, train_loss_step=0.996, image_AUROC=0.671, train_loss_epoch=4.180]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 70:  92%|█████████▏| 22/24 [00:03<00:00,  6.39it/s, loss=4.05, v_num=4, train_loss_step=0.996, image_AUROC=0.671, train_loss_epoch=4.180]
# Epoch 70:  96%|█████████▌| 23/24 [00:03<00:00,  6.30it/s, loss=4.05, v_num=4, train_loss_step=0.996, image_AUROC=0.671, train_loss_epoch=4.180]
# Epoch 70: 100%|██████████| 24/24 [00:03<00:00,  6.48it/s, loss=4.05, v_num=4, train_loss_step=0.996, image_AUROC=0.679, train_loss_epoch=4.180]
# Epoch 71:  88%|████████▊ | 21/24 [00:02<00:00,  9.56it/s, loss=4.04, v_num=4, train_loss_step=1.080, image_AUROC=0.679, train_loss_epoch=4.190]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 71:  92%|█████████▏| 22/24 [00:03<00:00,  6.73it/s, loss=4.04, v_num=4, train_loss_step=1.080, image_AUROC=0.679, train_loss_epoch=4.190]
# Epoch 71:  96%|█████████▌| 23/24 [00:03<00:00,  6.63it/s, loss=4.04, v_num=4, train_loss_step=1.080, image_AUROC=0.679, train_loss_epoch=4.190]
# Epoch 71: 100%|██████████| 24/24 [00:03<00:00,  6.81it/s, loss=4.04, v_num=4, train_loss_step=1.080, image_AUROC=0.638, train_loss_epoch=4.190]
# Epoch 72:  88%|████████▊ | 21/24 [00:02<00:00,  9.51it/s, loss=4.01, v_num=4, train_loss_step=1.070, image_AUROC=0.638, train_loss_epoch=4.170]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 72:  92%|█████████▏| 22/24 [00:03<00:00,  6.73it/s, loss=4.01, v_num=4, train_loss_step=1.070, image_AUROC=0.638, train_loss_epoch=4.170]
# Epoch 72:  96%|█████████▌| 23/24 [00:03<00:00,  6.61it/s, loss=4.01, v_num=4, train_loss_step=1.070, image_AUROC=0.638, train_loss_epoch=4.170]
# Epoch 72: 100%|██████████| 24/24 [00:03<00:00,  6.79it/s, loss=4.01, v_num=4, train_loss_step=1.070, image_AUROC=0.652, train_loss_epoch=4.170]
# Epoch 73:  88%|████████▊ | 21/24 [00:02<00:00,  8.87it/s, loss=3.97, v_num=4, train_loss_step=1.020, image_AUROC=0.652, train_loss_epoch=4.140]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 73:  92%|█████████▏| 22/24 [00:03<00:00,  6.44it/s, loss=3.97, v_num=4, train_loss_step=1.020, image_AUROC=0.652, train_loss_epoch=4.140]
# Epoch 73:  96%|█████████▌| 23/24 [00:03<00:00,  6.34it/s, loss=3.97, v_num=4, train_loss_step=1.020, image_AUROC=0.652, train_loss_epoch=4.140]
# Epoch 73: 100%|██████████| 24/24 [00:03<00:00,  6.52it/s, loss=3.97, v_num=4, train_loss_step=1.020, image_AUROC=0.654, train_loss_epoch=4.140]
# Epoch 74:  88%|████████▊ | 21/24 [00:02<00:00,  9.39it/s, loss=3.93, v_num=4, train_loss_step=1.060, image_AUROC=0.654, train_loss_epoch=4.100]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 74:  92%|█████████▏| 22/24 [00:03<00:00,  6.66it/s, loss=3.93, v_num=4, train_loss_step=1.060, image_AUROC=0.654, train_loss_epoch=4.100]
# Epoch 74:  96%|█████████▌| 23/24 [00:03<00:00,  6.56it/s, loss=3.93, v_num=4, train_loss_step=1.060, image_AUROC=0.654, train_loss_epoch=4.100]
# Epoch 74: 100%|██████████| 24/24 [00:03<00:00,  6.75it/s, loss=3.93, v_num=4, train_loss_step=1.060, image_AUROC=0.669, train_loss_epoch=4.100]
# Epoch 75:  88%|████████▊ | 21/24 [00:02<00:00,  9.49it/s, loss=3.91, v_num=4, train_loss_step=1.010, image_AUROC=0.669, train_loss_epoch=4.040]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 75:  92%|█████████▏| 22/24 [00:03<00:00,  6.79it/s, loss=3.91, v_num=4, train_loss_step=1.010, image_AUROC=0.669, train_loss_epoch=4.040]
# Epoch 75:  96%|█████████▌| 23/24 [00:03<00:00,  6.67it/s, loss=3.91, v_num=4, train_loss_step=1.010, image_AUROC=0.669, train_loss_epoch=4.040]
# Epoch 75: 100%|██████████| 24/24 [00:03<00:00,  6.86it/s, loss=3.91, v_num=4, train_loss_step=1.010, image_AUROC=0.629, train_loss_epoch=4.040]
# Epoch 76:  88%|████████▊ | 21/24 [00:02<00:00,  9.63it/s, loss=3.92, v_num=4, train_loss_step=1.100, image_AUROC=0.629, train_loss_epoch=4.030]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 76:  92%|█████████▏| 22/24 [00:03<00:00,  6.77it/s, loss=3.92, v_num=4, train_loss_step=1.100, image_AUROC=0.629, train_loss_epoch=4.030]
# Epoch 76:  96%|█████████▌| 23/24 [00:03<00:00,  6.66it/s, loss=3.92, v_num=4, train_loss_step=1.100, image_AUROC=0.629, train_loss_epoch=4.030]
# Epoch 76: 100%|██████████| 24/24 [00:03<00:00,  6.85it/s, loss=3.92, v_num=4, train_loss_step=1.100, image_AUROC=0.629, train_loss_epoch=4.030]
# Epoch 77:  88%|████████▊ | 21/24 [00:02<00:00,  9.49it/s, loss=3.82, v_num=4, train_loss_step=1.020, image_AUROC=0.629, train_loss_epoch=4.030]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 77:  92%|█████████▏| 22/24 [00:03<00:00,  6.71it/s, loss=3.82, v_num=4, train_loss_step=1.020, image_AUROC=0.629, train_loss_epoch=4.030]
# Epoch 77:  96%|█████████▌| 23/24 [00:03<00:00,  6.62it/s, loss=3.82, v_num=4, train_loss_step=1.020, image_AUROC=0.629, train_loss_epoch=4.030]
# Epoch 77: 100%|██████████| 24/24 [00:03<00:00,  6.81it/s, loss=3.82, v_num=4, train_loss_step=1.020, image_AUROC=0.673, train_loss_epoch=4.030]
# Epoch 78:  88%|████████▊ | 21/24 [00:02<00:00,  9.47it/s, loss=3.85, v_num=4, train_loss_step=0.995, image_AUROC=0.673, train_loss_epoch=3.930]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 78:  92%|█████████▏| 22/24 [00:03<00:00,  6.74it/s, loss=3.85, v_num=4, train_loss_step=0.995, image_AUROC=0.673, train_loss_epoch=3.930]
# Epoch 78:  96%|█████████▌| 23/24 [00:03<00:00,  6.59it/s, loss=3.85, v_num=4, train_loss_step=0.995, image_AUROC=0.673, train_loss_epoch=3.930]
# Epoch 78: 100%|██████████| 24/24 [00:03<00:00,  6.78it/s, loss=3.85, v_num=4, train_loss_step=0.995, image_AUROC=0.669, train_loss_epoch=3.930]
# Epoch 79:  88%|████████▊ | 21/24 [00:02<00:00,  9.34it/s, loss=3.84, v_num=4, train_loss_step=1.160, image_AUROC=0.669, train_loss_epoch=3.970]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 79:  92%|█████████▏| 22/24 [00:03<00:00,  6.57it/s, loss=3.84, v_num=4, train_loss_step=1.160, image_AUROC=0.669, train_loss_epoch=3.970]
# Epoch 79:  96%|█████████▌| 23/24 [00:03<00:00,  6.53it/s, loss=3.84, v_num=4, train_loss_step=1.160, image_AUROC=0.669, train_loss_epoch=3.970]
# Epoch 79: 100%|██████████| 24/24 [00:03<00:00,  6.71it/s, loss=3.84, v_num=4, train_loss_step=1.160, image_AUROC=0.633, train_loss_epoch=3.970]
# Epoch 80:  88%|████████▊ | 21/24 [00:02<00:00,  9.08it/s, loss=3.82, v_num=4, train_loss_step=1.070, image_AUROC=0.633, train_loss_epoch=3.950]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 80:  92%|█████████▏| 22/24 [00:03<00:00,  6.54it/s, loss=3.82, v_num=4, train_loss_step=1.070, image_AUROC=0.633, train_loss_epoch=3.950]
# Epoch 80:  96%|█████████▌| 23/24 [00:03<00:00,  6.44it/s, loss=3.82, v_num=4, train_loss_step=1.070, image_AUROC=0.633, train_loss_epoch=3.950]
# Epoch 80: 100%|██████████| 24/24 [00:03<00:00,  6.63it/s, loss=3.82, v_num=4, train_loss_step=1.070, image_AUROC=0.669, train_loss_epoch=3.950]
# Epoch 80: 100%|██████████| 24/24 [00:03<00:00,  6.61it/s, loss=3.82, v_num=4, train_loss_step=1.070, image_AUROC=0.669, train_loss_epoch=3.940]

# %% [markdown]
# The training has finished after 12 epochs. This is because, we set the `EarlyStopping` criteria with a patience of 3, which terminated the training after `pixel_AUROC` stopped improving. If we increased the `patience`, the training would continue further.
#
# ## Testing
#
# Now that we trained the model, we could test the model to check the overall performance on the test set. We will also be writing the output of the test images to a file since we set `VisualizerCallback` in `callbacks`.

# %%
test_datamodule = Folder(
    root="/scratch/ssenth21/aggr_miniJSRT/test/",
    normal_dir="org",
    abnormal_dir="flip",
    task=task,
    image_size=256,
    #normalization=InputNormalizationMethod.NONE,  # don't apply normalization, as we want to visualize the images
)
test_datamodule.setup()
trainer.test(datamodule=test_datamodule, model=model)
# Out:
# /home/ssenth21/.conda/envs/anomalib_env/lib/python3.8/site-packages/lightning_fabric/plugins/environments/slurm.py:166: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /home/ssenth21/.conda/envs/anomalib_env/lib/python3. ...
#   rank_zero_warn(
# /home/ssenth21/.conda/envs/anomalib_env/lib/python3.8/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `ROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 1/1 [00:12<00:00, 12.07s/it]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        image_AUROC          0.7416666746139526
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'image_AUROC': 0.7416666746139526}]

# %%
trainer.test(datamodule=datamodule, model=model)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 3/3 [00:11<00:00,  3.96s/it]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        image_AUROC          0.6893004179000854
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'image_AUROC': 0.6893004179000854}]

# %% [markdown]
# `trainer.test` returns the `pixel_AUROC` and `image_AUROC` results. We could also find the saved output in `images` directory.

# %%
# !ls images
# Out:
# ls: cannot access images: No such file or directory

# %% [markdown]
# ## Inference
#
# Since we have a trained model, we could infer the model on an individual image or folder of images. Anomalib has an `InferenceDataset` to let you create an inference dataset. So let's try it.

# %%
dataset_root
# Out:
# '/scratch/ssenth21/aggr_miniJSRT'

# %%
inference_dataset = InferenceDataset(path="/scratch/ssenth21/aggr_miniJSRT/test/org", image_size=(256, 256))
#inference_dataset = InferenceDataset(path=dataset_root / "autoencoder_img/newFlip/case237.tif", image_size=(256, 256))
inference_dataloader = DataLoader(dataset=inference_dataset)

# %% [markdown]
# We could utilize `Trainer`'s `predict` method to infer, and get the outputs to visualize

# %%
predictions = trainer.predict(model=model, dataloaders=inference_dataloader)[0]
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/ssenth21/.conda/envs/anomalib_env/lib/python3.8/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, predict_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 40 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Predicting DataLoader 0: 100%|██████████| 202/202 [00:49<00:00,  4.12it/s]

# %% [markdown]
# `predictions` contain image, anomaly maps, predicted scores, labels and masks. These are all stored in a dictionary. We could check this by printing the `prediction` keys.

# %%
predictions
# Out:
# {'image': tensor([[[[ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489],
#            [ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489],
#            [ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489],
#            ...,
#            [ 0.1083, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [ 0.0912, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [ 0.0741, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179]],
#
#           [[ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286],
#            [ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286],
#            [ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286],
#            ...,
#            [ 0.2402, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [ 0.2227, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [ 0.2052, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357]],
#
#           [[ 2.6400,  2.6400,  2.6400,  ...,  2.6400,  2.6400,  2.6400],
#            [ 2.6400,  2.6400,  2.6400,  ...,  2.6400,  2.6400,  2.6400],
#            [ 2.6400,  2.6400,  2.6400,  ...,  2.6400,  2.6400,  2.6400],
#            ...,
#            [ 0.4614, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [ 0.4439, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [ 0.4265, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044]]]]),
#  'image_path': ['/scratch/ssenth21/aggr_miniJSRT/test/org/org_95_case196.bmp'],
#  'anomaly_maps': tensor([[[[0.0049, 0.0049, 0.0047,  ..., 0.0026, 0.0025, 0.0025],
#            [0.0049, 0.0049, 0.0047,  ..., 0.0026, 0.0025, 0.0025],
#            [0.0044, 0.0044, 0.0042,  ..., 0.0024, 0.0023, 0.0023],
#            ...,
#            [0.0011, 0.0011, 0.0011,  ..., 0.0004, 0.0005, 0.0005],
#            [0.0011, 0.0011, 0.0011,  ..., 0.0005, 0.0005, 0.0005],
#            [0.0011, 0.0011, 0.0011,  ..., 0.0005, 0.0005, 0.0005]]]]),
#  'pred_scores': tensor([0.0118]),
#  'pred_labels': tensor([True]),
#  'pred_masks': tensor([[[[False, False, False,  ..., False, False, False],
#            [False, False, False,  ..., False, False, False],
#            [False, False, False,  ..., False, False, False],
#            ...,
#            [False, False, False,  ..., False, False, False],
#            [False, False, False,  ..., False, False, False],
#            [False, False, False,  ..., False, False, False]]]]),
#  'pred_boxes': [tensor([[227.,   0., 232.,   2.],
#           [ 56., 245.,  60., 247.]])],
#  'box_scores': [tensor([0.0107, 0.0118])],
#  'box_labels': [tensor([1., 1.])]}

# %%
print(predictions.keys())
# Out:
# dict_keys(['image', 'image_path', 'anomaly_maps', 'pred_scores', 'pred_labels', 'pred_masks', 'pred_boxes', 'box_scores', 'box_labels'])

# %%
print(
    f'Image Shape: {predictions["image"].shape},\n'
    'Anomaly Map Shape: {predictions["anomaly_maps"].shape}, \n'
    'Predicted Mask Shape: {predictions["pred_masks"].shape}'
)
# Out:
# Image Shape: torch.Size([1, 3, 256, 256]),
# Anomaly Map Shape: {predictions["anomaly_maps"].shape},
# Predicted Mask Shape: {predictions["pred_masks"].shape}

# %% [markdown]
# ## Visualization

# %% [markdown]
# To properly visualize the predictions, we will need to perform some post-processing operations.
#
# Let's post-process each output one by one. We could start with the image. Each `image` is a tensor and within (0, 1) range. To visualize it, we need to denormalize it to (0, 255) scale. Anomalib already has a class for this. Let's use it.

# %%
image = predictions["image"]
image = Denormalize()(image)
print(f"Image Shape: {image.shape}\n Min Pixel: {image.min()} \n Max Pixel: {image.max()}")
# Out:
# Image Shape: (256, 256, 3)
#  Min Pixel: 0
#  Max Pixel: 255
# /scratch/ssenth21/anomalib/src/anomalib/pre_processing/transforms/custom.py:25: UserWarning: Denormalize is no longer used and will be deprecated in v0.4.0
#   warnings.warn("Denormalize is no longer used and will be deprecated in v0.4.0")

# %% [markdown]
# We could now see that `image` is of a numpy array and within the range of \[0, 255\]. It's ready to be visualized now.

# %%
plt.imshow(image)

# %% [markdown]
# The second output of the predictions is the anomaly map. As can be seen above, it's also a torch tensor and of size `torch.Size([1, 1, 256, 256])`. We therefore need to convert it to numpy and squeeze the dimensions to make it `256x256` output to visualize.

# %%
anomaly_map = predictions["anomaly_maps"]
anomaly_map = anomaly_map.cpu().numpy().squeeze()
plt.imshow(anomaly_map)

# %% [markdown]
# We could superimpose (overlay) the anomaly map on top of the original image to get a heat map. Anomalib has a built-in function to achieve this. Let's try it.

# %%
heat_map = superimpose_anomaly_map(anomaly_map=anomaly_map, image=image, normalize=True)
plt.imshow(heat_map)

# %% [markdown]
# `predictions` also contains prediction scores and labels.

# %%
pred_score = predictions["pred_scores"]
pred_labels = predictions["pred_labels"]
print(pred_score, pred_labels)
# Out:
# tensor([0.0118]) tensor([True])

# %% [markdown]
# The last part of the predictions is the mask that is predicted by the model. This is a boolean mask containing True/False for the abnormal/normal pixels, respectively.

# %%
pred_masks = predictions["pred_masks"].squeeze().cpu().numpy()
plt.imshow(pred_masks)

# %% [markdown]
# That wraps it! In this notebook, we show how we could train, test and finally infer a FastFlow model using Anomalib API.
